# %%
path = r".\nn.txt"
with open(path, "r") as f:
    data = f.read().split()

n_layers = int(data[0])
layers = []
print(n_layers)
for i in range(n_layers):
    layers.append(int(data[i+1]))
layers
# Out:
# 2
# [4, 3]
